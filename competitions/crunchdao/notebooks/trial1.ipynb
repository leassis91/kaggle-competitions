# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_parquet('../data/X_train.parquet', engine='pyarrow')
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train = pd.read_parquet('../data/X_train.parquet', engine='pyarrow')
#
# File ~/kaggle/competitions/crunchdao/.venv/lib/python3.10/site-packages/pandas/io/parquet.py:653, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     500 @doc(storage_options=_shared_docs["storage_options"])
#     501 def read_parquet(
#     502     path: FilePath | ReadBuffer[bytes],
#    (...)
#     510     **kwargs,
#     511 ) -> DataFrame:
#     512     """
#     513     Load a parquet object from the file path, returning a DataFrame.
#     514
#    (...)
#     650     1    4    9
#     651     """
# --> 653     impl = get_engine(engine)
#     655     if use_nullable_dtypes is not lib.no_default:
#     656         msg = (
# ...
